# %%
from google.cloud import bigquery
from src.jobs import Jobs
from src.plotter import Plotter

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# from SDK

# %%
client = bigquery.Client.from_service_account_json('../credentials.json')

# %%
jobs = Jobs.fetch(client)
# Out:
# {'projectId': 'bq-playground-278116', 'datasetId': '_031161baee28c379a5ba5f7517c8e9b08122df00', 'tableId': 'anon9ed985171dbaf41ec29ed784ca8b5073087ed7d3'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-a82c297b353a> in <module>
# ----> 1 jobs = Jobs.fetch(client)
#
# ~/dev/bq-dashboard/nbs/src/jobs.py in fetch(client)
#      25     def fetch(client):
#      26         google_jobs = list(client.list_jobs(all_users=True))
# ---> 27         _jobs = list(map(Job.from_google_job, google_jobs))
#      28         jobs = Jobs(_jobs)
#      29         return jobs
#
# ~/dev/bq-dashboard/nbs/src/job.py in from_google_job(cls, job)
#      53     @classmethod
#      54     def from_google_job(cls, job):
# ---> 55         instance = cls(job.job_id, job.job_type, job.created, job.started, job.ended, Job._destination(job.destination),
# ...

# %%
Plotter.plot_timeline(df=jobs.query_plan_timelines, x="start", x2="end", y="destination", color="interval_type").interactive()

# %%
# from JSON

# %%
jobs = Jobs.from_json('/home/ziggyzacks/Downloads/example-jobs-2.json')

# %%
Plotter.plot_timeline(df=jobs.query_plan_timelines, x="start", x2="end", y="destination", color="interval_type").interactive()
# Out:
# alt.Chart(...)

# %%
Plotter.plot_timeline(df=jobs.job_timelines, x="started", x2="ended", y="destination", color="job_type").interactive()
# Out:
# alt.Chart(...)
